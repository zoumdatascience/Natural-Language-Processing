# %% [markdown]
# # Extract Images from word document
# ![image.png](attachment:image.png)

# %%
# !pip install docx2txt
# Out:
# ...
# WARNING: You are using pip version 20.0.2; however, version 20.3.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.6/bin/python3.6 -m pip install --upgrade pip' command.

# %%
import docx2txt as d2t

# %%
"""
This function extracts images (and text if needed) from a word file
"""
def extract_images_from_docx(path_to_file, images_folder, get_text=False):
    """
    @params:
        - path_to_file: path to the word file
        - images_folder: the folder that will contain the extracted images
        - get_text: the parameter used to specify if there is a need to return the text data
                    the default value is false, which means that the function only extract images
    """
    text = d2t.process(path_to_file, images_folder) 
    
    if(get_text):
        return text

# %%
path_to_file = './data/Obama_Speech.docx'
images_folder = './images/'

# %%
'''
This is the example for ONLY extracting images. 
As you might notice, I didn't specify the get_text parameter, in what case the default value(FALSE)
will  be used. Feel free to uncomment the following instruction to test it yourself
'''
#extract_images_from_docx(path_to_file, images_folder)

# %%
'''
This is the example for extracting both images and text. To do so, I MUST change the get_text value 
to True while calling the function
'''
data = extract_images_from_docx(path_to_file, images_folder, get_text=True)

# %%
'''
Uncomment if you want to see the text data
'''
#print(data)
